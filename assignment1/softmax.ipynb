# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.406207
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*
# With random initial weights, the log-likelihood for each class is expected to be the same. So -log(1/N) = -log(0.1)

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.097083 analytic: 1.097083, relative error: 6.309286e-08
# numerical: 1.839339 analytic: 1.839339, relative error: 3.284557e-08
# numerical: -2.608125 analytic: -2.608125, relative error: 1.144416e-08
# numerical: -0.678083 analytic: -0.678083, relative error: 2.030964e-08
# numerical: -0.157040 analytic: -0.157040, relative error: 1.206246e-07
# numerical: -1.392941 analytic: -1.392941, relative error: 4.116706e-08
# numerical: -1.118204 analytic: -1.118205, relative error: 5.799107e-08
# numerical: 0.015356 analytic: 0.015356, relative error: 2.487563e-07
# numerical: -3.380176 analytic: -3.380176, relative error: 2.410143e-08
# numerical: -0.426807 analytic: -0.426807, relative error: 1.599080e-08
# numerical: 1.003528 analytic: 1.003528, relative error: 2.055234e-08
# numerical: 0.156626 analytic: 0.156626, relative error: 5.615658e-08
# numerical: -3.766693 analytic: -3.766693, relative error: 1.938506e-09
# numerical: -4.343860 analytic: -4.343860, relative error: 1.459487e-08
# numerical: -0.153929 analytic: -0.153929, relative error: 1.283101e-07
# numerical: -3.382609 analytic: -3.382609, relative error: 1.798827e-08
# numerical: -0.285720 analytic: -0.285720, relative error: 1.919111e-08
# numerical: 2.060374 analytic: 2.060374, relative error: 2.297992e-08
# numerical: 0.846518 analytic: 0.846518, relative error: 3.439371e-08
# numerical: 2.701156 analytic: 2.701156, relative error: 1.463922e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.406207e+00 computed in 0.128294s
# vectorized loss: 2.406207e+00 computed in 0.005755s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
#learning_rates = [1e-7, 5e-7]
#regularization_strengths = [2.5e4, 5e4]

learning_rates = np.log10([1e-7, 5e-6])
regularization_strengths = np.log10([5e3, 6e4])

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

#just copied from svm...
#num_params = 100
num_params=50
range_lr = np.logspace(learning_rates[0],learning_rates[1],num_params)
range_reg = np.logspace(regularization_strengths[0],regularization_strengths[1],num_params)

range_lr = range_lr[np.random.permutation(num_params)]
range_reg = range_reg[np.random.permutation(num_params)]

for learning_rate, regularization_strength in zip(range_lr, range_reg):
    #train
    print("Starting iteration with rate %e and regstrength %e"%(learning_rate,regularization_strength))
    softmax = Softmax()
    loss_hist = softmax.train(X_train, y_train, learning_rate=learning_rate, reg=regularization_strength,
                              num_iters=500, verbose=True)
    
    y_train_pred = softmax.predict(X_train)
    train_acc = np.mean(y_train == y_train_pred)
    print('training accuracy: %f' % train_acc)
    y_val_pred = softmax.predict(X_val)
    val_acc = np.mean(y_val == y_val_pred)
    print('validation accuracy: %f' % val_acc)
    print('\n')
    
    results[(learning_rate,regularization_strength)]=(train_acc,val_acc)
    if val_acc > best_val:
        best_val = val_acc
        best_softmax = softmax


################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Starting iteration with rate 2.221921e-07 and regstrength 1.184077e+04
# iteration 0 / 500: loss 367.951608
# iteration 100 / 500: loss 127.808815
# iteration 200 / 500: loss 45.372869
# iteration 300 / 500: loss 17.201688
# iteration 400 / 500: loss 7.276234
# training accuracy: 0.342878
# validation accuracy: 0.352000
#
#
# Starting iteration with rate 2.823236e-07 and regstrength 6.778204e+03
# iteration 0 / 500: loss 214.427396
# iteration 100 / 500: loss 98.630444
# iteration 200 / 500: loss 46.565802
# iteration 300 / 500: loss 22.562790
# iteration 400 / 500: loss 11.479858
# training accuracy: 0.342857
# validation accuracy: 0.356000
#
#
# Starting iteration with rate 5.791657e-07 and regstrength 2.289250e+04
# iteration 0 / 500: loss 693.481730
# iteration 100 / 500: loss 5.251391
# iteration 200 / 500: loss 2.118454
# iteration 300 / 500: loss 2.130144
# iteration 400 / 500: loss 2.086588
# training accuracy: 0.324020
# validation accuracy: 0.332000
#
#
# Starting iteration with rate 1.771018e-06 and regstrength 1.868946e+04
# iteration 0 / 500: loss 581.475343
# iteration 100 / 500: loss 2.078663
# iteration 200 / 500: loss 2.065044
# iteration 300 / 500: loss 2.121160
# iteration 400 / 500: loss 2.053831
# training accuracy: 0.324898
# validation accuracy: 0.337000
#
#
# Starting iteration with rate 1.012775e-06 and regstrength 2.408337e+04
# iteration 0 / 500: loss 742.533138
# iteration 100 / 500: loss 2.117353
# iteration 200 / 500: loss 2.101440
# iteration 300 / 500: loss 2.047413
# iteration 400 / 500: loss 2.079102
# training accuracy: 0.330694
# validation accuracy: 0.347000
#
#
# Starting iteration with rate 2.051425e-07 and regstrength 9.666815e+03
# iteration 0 / 500: loss 299.084837
# iteration 100 / 500: loss 135.173830
# iteration 200 / 500: loss 61.917078
# iteration 300 / 500: loss 28.962860
# iteration 400 / 500: loss 14.116820
# training accuracy: 0.331429
# validation accuracy: 0.343000
#
#
# Starting iteration with rate 5.347244e-07 and regstrength 6.443036e+03
# iteration 0 / 500: loss 201.012523
# iteration 100 / 500: loss 51.006380
# iteration 200 / 500: loss 14.163208
# iteration 300 / 500: loss 5.124052
# iteration 400 / 500: loss 2.662038
# training accuracy: 0.366816
# validation accuracy: 0.378000
#
#
# Starting iteration with rate 3.312019e-07 and regstrength 1.125526e+04
# iteration 0 / 500: loss 352.574201
# iteration 100 / 500: loss 79.548720
# iteration 200 / 500: loss 19.325290
# iteration 300 / 500: loss 5.863365
# iteration 400 / 500: loss 2.893922
# training accuracy: 0.348020
# validation accuracy: 0.364000
#
#
# Starting iteration with rate 6.273006e-07 and regstrength 6.124441e+03
# iteration 0 / 500: loss 192.860053
# iteration 100 / 500: loss 41.673459
# iteration 200 / 500: loss 10.363382
# iteration 300 / 500: loss 3.706519
# iteration 400 / 500: loss 2.290473
# training accuracy: 0.366265
# validation accuracy: 0.380000
#
#
# Starting iteration with rate 9.350611e-07 and regstrength 8.734442e+03
# iteration 0 / 500: loss 272.499123
# iteration 100 / 500: loss 11.748752
# iteration 200 / 500: loss 2.448609
# iteration 300 / 500: loss 1.963824
# iteration 400 / 500: loss 2.016216
# training accuracy: 0.356531
# validation accuracy: 0.368000
#
#
# Starting iteration with rate 1.188115e-06 and regstrength 6.000000e+04
# iteration 0 / 500: loss 1855.948497
# iteration 100 / 500: loss 2.163187
# iteration 200 / 500: loss 2.151768
# iteration 300 / 500: loss 2.204403
# iteration 400 / 500: loss 2.185162
# training accuracy: 0.298020
# validation accuracy: 0.314000
#
#
# Starting iteration with rate 2.437330e-06 and regstrength 1.245673e+04
# iteration 0 / 500: loss 386.961089
# iteration 100 / 500: loss 1.987393
# iteration 200 / 500: loss 2.073593
# iteration 300 / 500: loss 2.117594
# iteration 400 / 500: loss 2.117241
# training accuracy: 0.326245
# validation accuracy: 0.334000
#
#
# Starting iteration with rate 3.096940e-06 and regstrength 3.264840e+04
# iteration 0 / 500: loss 1001.098150
# iteration 100 / 500: loss 2.159813
# iteration 200 / 500: loss 2.164372
# iteration 300 / 500: loss 2.228271
# iteration 400 / 500: loss 2.168103
# training accuracy: 0.267265
# validation accuracy: 0.278000
#
#
# Starting iteration with rate 2.406586e-07 and regstrength 3.801319e+04
# iteration 0 / 500: loss 1187.912324
# iteration 100 / 500: loss 31.395675
# iteration 200 / 500: loss 2.896222
# iteration 300 / 500: loss 2.112860
# iteration 400 / 500: loss 2.154399
# training accuracy: 0.318163
# validation accuracy: 0.327000
#
#
# Starting iteration with rate 1.614497e-07 and regstrength 3.103401e+04
# iteration 0 / 500: loss 950.505103
# iteration 100 / 500: loss 127.998279
# iteration 200 / 500: loss 18.781313
# iteration 300 / 500: loss 4.311580
# iteration 400 / 500: loss 2.428571
# training accuracy: 0.319102
# validation accuracy: 0.338000
#
#
# Starting iteration with rate 1.270628e-07 and regstrength 4.425951e+04
# iteration 0 / 500: loss 1360.861406
# iteration 100 / 500: loss 142.969885
# iteration 200 / 500: loss 16.752629
# iteration 300 / 500: loss 3.677050
# iteration 400 / 500: loss 2.321268
# training accuracy: 0.312980
# validation accuracy: 0.331000
#
#
# Starting iteration with rate 1.096947e-06 and regstrength 7.130808e+03
# iteration 0 / 500: loss 225.618917
# iteration 100 / 500: loss 11.250335
# iteration 200 / 500: loss 2.381093
# iteration 300 / 500: loss 2.019914
# iteration 400 / 500: loss 1.941518
# training accuracy: 0.358184
# validation accuracy: 0.355000
#
#
# Starting iteration with rate 8.633107e-07 and regstrength 5.000000e+03
# iteration 0 / 500: loss 160.684786
# iteration 100 / 500: loss 29.100496
# iteration 200 / 500: loss 6.632894
# iteration 300 / 500: loss 2.750441
# iteration 400 / 500: loss 2.053774
# training accuracy: 0.371878
# validation accuracy: 0.382000
#
#
# Starting iteration with rate 4.262106e-06 and regstrength 2.068450e+04
# iteration 0 / 500: loss 649.176832
# iteration 100 / 500: loss 2.285633
# iteration 200 / 500: loss 2.294154
# iteration 300 / 500: loss 2.306177
# iteration 400 / 500: loss 2.147811
# training accuracy: 0.299102
# validation accuracy: 0.305000
#
#
# Starting iteration with rate 2.606599e-07 and regstrength 1.378644e+04
# iteration 0 / 500: loss 431.927870
# iteration 100 / 500: loss 102.384922
# iteration 200 / 500: loss 25.690629
# iteration 300 / 500: loss 7.494156
# iteration 400 / 500: loss 3.272090
# training accuracy: 0.339592
# validation accuracy: 0.351000
#
#
# Starting iteration with rate 2.859302e-06 and regstrength 1.776531e+04
# iteration 0 / 500: loss 547.452669
# iteration 100 / 500: loss 2.127885
# iteration 200 / 500: loss 2.139014
# iteration 300 / 500: loss 2.080667
# iteration 400 / 500: loss 2.097831
# training accuracy: 0.311347
# validation accuracy: 0.322000
#
#
# Starting iteration with rate 6.794360e-07 and regstrength 3.613351e+04
# iteration 0 / 500: loss 1118.293325
# iteration 100 / 500: loss 2.137583
# iteration 200 / 500: loss 2.148084
# iteration 300 / 500: loss 2.128166
# iteration 400 / 500: loss 2.128750
# training accuracy: 0.311531
# validation accuracy: 0.341000
#
#
# Starting iteration with rate 1.393812e-06 and regstrength 5.533733e+03
# iteration 0 / 500: loss 176.002108
# iteration 100 / 500: loss 9.485860
# iteration 200 / 500: loss 2.248993
# iteration 300 / 500: loss 1.982002
# iteration 400 / 500: loss 2.110048
# training accuracy: 0.362347
# validation accuracy: 0.374000
#
#
# Starting iteration with rate 3.587284e-07 and regstrength 1.688685e+04
# iteration 0 / 500: loss 523.517760
# iteration 100 / 500: loss 46.898349
# iteration 200 / 500: loss 5.880445
# iteration 300 / 500: loss 2.419794
# iteration 400 / 500: loss 2.096516
# training accuracy: 0.338918
# validation accuracy: 0.363000
#
#
# Starting iteration with rate 1.286860e-06 and regstrength 5.821600e+03
# iteration 0 / 500: loss 183.800832
# iteration 100 / 500: loss 10.475176
# iteration 200 / 500: loss 2.354674
# iteration 300 / 500: loss 1.943461
# iteration 400 / 500: loss 1.978405
# training accuracy: 0.351592
# validation accuracy: 0.357000
#
#
# Starting iteration with rate 1.376231e-07 and regstrength 9.188810e+03
# iteration 0 / 500: loss 288.969614
# iteration 100 / 500: loss 173.691867
# iteration 200 / 500: loss 104.804376
# iteration 300 / 500: loss 63.806023
# iteration 400 / 500: loss 39.068084
# training accuracy: 0.280592
# validation accuracy: 0.266000
#
#
# Starting iteration with rate 1.635121e-06 and regstrength 8.302542e+03
# iteration 0 / 500: loss 260.269302
# iteration 100 / 500: loss 3.040572
# iteration 200 / 500: loss 2.042434
# iteration 300 / 500: loss 2.002116
# iteration 400 / 500: loss 2.003830
# training accuracy: 0.350612
# validation accuracy: 0.347000
#
#
# Starting iteration with rate 3.633110e-06 and regstrength 1.016969e+04
# iteration 0 / 500: loss 316.610252
# iteration 100 / 500: loss 2.081474
# iteration 200 / 500: loss 1.998987
# iteration 300 / 500: loss 2.123014
# iteration 400 / 500: loss 2.043975
# training accuracy: 0.323592
# validation accuracy: 0.320000
#
#
# Starting iteration with rate 3.354329e-06 and regstrength 1.605183e+04
# iteration 0 / 500: loss 498.916382
# iteration 100 / 500: loss 2.197705
# iteration 200 / 500: loss 2.138612
# iteration 300 / 500: loss 2.088139
# iteration 400 / 500: loss 2.057069
# training accuracy: 0.317980
# validation accuracy: 0.317000
#
#
# Starting iteration with rate 3.057877e-07 and regstrength 2.176051e+04
# iteration 0 / 500: loss 681.890944
# iteration 100 / 500: loss 48.230470
# iteration 200 / 500: loss 5.254600
# iteration 300 / 500: loss 2.361412
# iteration 400 / 500: loss 2.054361
# training accuracy: 0.335020
# validation accuracy: 0.350000
#
#
# Starting iteration with rate 2.250305e-06 and regstrength 5.703312e+04
# iteration 0 / 500: loss 1761.199910
# iteration 100 / 500: loss 2.142836
# iteration 200 / 500: loss 2.181883
# iteration 300 / 500: loss 2.237524
# iteration 400 / 500: loss 2.209392
# training accuracy: 0.279776
# validation accuracy: 0.287000
#
#
# Starting iteration with rate 7.359045e-07 and regstrength 5.153223e+04
# iteration 0 / 500: loss 1592.542897
# iteration 100 / 500: loss 2.185422
# iteration 200 / 500: loss 2.156137
# iteration 300 / 500: loss 2.092689
# iteration 400 / 500: loss 2.166796
# training accuracy: 0.285327
# validation accuracy: 0.287000
#
#
# Starting iteration with rate 1.000000e-07 and regstrength 4.207097e+04
# iteration 0 / 500: loss 1301.673585
# iteration 100 / 500: loss 240.832622
# iteration 200 / 500: loss 46.045074
# iteration 300 / 500: loss 10.206910
# iteration 400 / 500: loss 3.620258
# training accuracy: 0.312102
# validation accuracy: 0.332000
#
#
# Starting iteration with rate 1.083111e-07 and regstrength 5.260101e+03
# iteration 0 / 500: loss 168.222907
# iteration 100 / 500: loss 132.798681
# iteration 200 / 500: loss 105.748921
# iteration 300 / 500: loss 84.169474
# iteration 400 / 500: loss 67.219099
# training accuracy: 0.222286
# validation accuracy: 0.263000
#
#
# Starting iteration with rate 1.509653e-06 and regstrength 1.525810e+04
# iteration 0 / 500: loss 480.709366
# iteration 100 / 500: loss 2.070977
# iteration 200 / 500: loss 2.041407
# iteration 300 / 500: loss 2.063643
# iteration 400 / 500: loss 2.021167
# training accuracy: 0.336429
# validation accuracy: 0.346000
#
#
# Starting iteration with rate 4.936932e-07 and regstrength 1.310473e+04
# iteration 0 / 500: loss 405.880673
# iteration 100 / 500: loss 31.431841
# iteration 200 / 500: loss 4.189634
# iteration 300 / 500: loss 2.204680
# iteration 400 / 500: loss 2.120713
# training accuracy: 0.348898
# validation accuracy: 0.359000
#
#
# Starting iteration with rate 1.173129e-07 and regstrength 1.450361e+04
# iteration 0 / 500: loss 444.746080
# iteration 100 / 500: loss 224.747004
# iteration 200 / 500: loss 114.013674
# iteration 300 / 500: loss 58.678364
# iteration 400 / 500: loss 30.493076
# training accuracy: 0.291816
# validation accuracy: 0.297000
#
#
# Starting iteration with rate 3.935061e-06 and regstrength 4.656190e+04
# iteration 0 / 500: loss 1440.864914
# iteration 100 / 500: loss 2.353136
# iteration 200 / 500: loss 2.211646
# iteration 300 / 500: loss 2.293490
# iteration 400 / 500: loss 2.560579
# training accuracy: 0.248959
# validation accuracy: 0.255000
#
#
# Starting iteration with rate 1.490611e-07 and regstrength 7.891998e+03
# iteration 0 / 500: loss 247.363443
# iteration 100 / 500: loss 153.549491
# iteration 200 / 500: loss 96.177274
# iteration 300 / 500: loss 60.634458
# iteration 400 / 500: loss 38.397896
# training accuracy: 0.279959
# validation accuracy: 0.299000
#
#
# Starting iteration with rate 4.558105e-07 and regstrength 5.421295e+04
# iteration 0 / 500: loss 1688.517449
# iteration 100 / 500: loss 2.250396
# iteration 200 / 500: loss 2.158789
# iteration 300 / 500: loss 2.109666
# iteration 400 / 500: loss 2.158352
# training accuracy: 0.292204
# validation accuracy: 0.301000
#
#
# Starting iteration with rate 1.748679e-07 and regstrength 7.501755e+03
# iteration 0 / 500: loss 240.271084
# iteration 100 / 500: loss 141.261856
# iteration 200 / 500: loss 83.828887
# iteration 300 / 500: loss 50.292857
# iteration 400 / 500: loss 30.337453
# training accuracy: 0.290265
# validation accuracy: 0.281000
#
#
# Starting iteration with rate 1.894013e-07 and regstrength 3.999064e+04
# iteration 0 / 500: loss 1233.494154
# iteration 100 / 500: loss 59.871067
# iteration 200 / 500: loss 4.861769
# iteration 300 / 500: loss 2.227479
# iteration 400 / 500: loss 2.138685
# training accuracy: 0.313612
# validation accuracy: 0.335000
#
#
# Starting iteration with rate 1.918208e-06 and regstrength 2.665419e+04
# iteration 0 / 500: loss 822.369214
# iteration 100 / 500: loss 2.147047
# iteration 200 / 500: loss 2.081563
# iteration 300 / 500: loss 2.054579
# iteration 400 / 500: loss 2.150816
# training accuracy: 0.313408
# validation accuracy: 0.307000
#
#
# Starting iteration with rate 4.208346e-07 and regstrength 1.966169e+04
# iteration 0 / 500: loss 607.777452
# iteration 100 / 500: loss 23.254541
# iteration 200 / 500: loss 2.773143
# iteration 300 / 500: loss 2.116624
# iteration 400 / 500: loss 2.055163
# training accuracy: 0.329102
# validation accuracy: 0.332000
#
#
# Starting iteration with rate 2.077632e-06 and regstrength 4.898406e+04
# iteration 0 / 500: loss 1522.800037
# iteration 100 / 500: loss 2.145908
# iteration 200 / 500: loss 2.226633
# iteration 300 / 500: loss 2.183078
# iteration 400 / 500: loss 2.160866
# training accuracy: 0.263959
# validation accuracy: 0.275000
#
#
# Starting iteration with rate 4.616333e-06 and regstrength 2.949944e+04
# iteration 0 / 500: loss 904.847689
# iteration 100 / 500: loss 2.312653
# iteration 200 / 500: loss 2.232069
# iteration 300 / 500: loss 2.281265
# iteration 400 / 500: loss 2.330709
# training accuracy: 0.200449
# validation accuracy: 0.202000
#
#
# Starting iteration with rate 2.639898e-06 and regstrength 2.533620e+04
# iteration 0 / 500: loss 778.991801
# iteration 100 / 500: loss 2.182385
# iteration 200 / 500: loss 2.077072
# iteration 300 / 500: loss 2.223589
# iteration 400 / 500: loss 2.111997
# training accuracy: 0.294367
# validation accuracy: 0.304000
#
#
# Starting iteration with rate 7.970660e-07 and regstrength 3.434678e+04
# iteration 0 / 500: loss 1053.335740
# iteration 100 / 500: loss 2.111569
# iteration 200 / 500: loss 2.121036
# iteration 300 / 500: loss 2.136573
# iteration 400 / 500: loss 2.124469
# training accuracy: 0.311143
# validation accuracy: 0.307000
#
#
# Starting iteration with rate 5.000000e-06 and regstrength 2.804075e+04
# iteration 0 / 500: loss 862.876043
# iteration 100 / 500: loss 2.329055
# iteration 200 / 500: loss 2.309047
# iteration 300 / 500: loss 3.032534
# iteration 400 / 500: loss 2.669054
# training accuracy: 0.230592
# validation accuracy: 0.251000
#
#
# Starting iteration with rate 3.885425e-07 and regstrength 1.069871e+04
# iteration 0 / 500: loss 330.687725
# iteration 100 / 500: loss 62.946540
# iteration 200 / 500: loss 13.419597
# iteration 300 / 500: loss 4.220778
# iteration 400 / 500: loss 2.415241
# training accuracy: 0.350633
# validation accuracy: 0.344000
#
#
# lr 1.000000e-07 reg 4.207097e+04 train accuracy: 0.312102 val accuracy: 0.332000
# lr 1.083111e-07 reg 5.260101e+03 train accuracy: 0.222286 val accuracy: 0.263000
# lr 1.173129e-07 reg 1.450361e+04 train accuracy: 0.291816 val accuracy: 0.297000
# lr 1.270628e-07 reg 4.425951e+04 train accuracy: 0.312980 val accuracy: 0.331000
# lr 1.376231e-07 reg 9.188810e+03 train accuracy: 0.280592 val accuracy: 0.266000
# lr 1.490611e-07 reg 7.891998e+03 train accuracy: 0.279959 val accuracy: 0.299000
# lr 1.614497e-07 reg 3.103401e+04 train accuracy: 0.319102 val accuracy: 0.338000
# lr 1.748679e-07 reg 7.501755e+03 train accuracy: 0.290265 val accuracy: 0.281000
# lr 1.894013e-07 reg 3.999064e+04 train accuracy: 0.313612 val accuracy: 0.335000
# lr 2.051425e-07 reg 9.666815e+03 train accuracy: 0.331429 val accuracy: 0.343000
# lr 2.221921e-07 reg 1.184077e+04 train accuracy: 0.342878 val accuracy: 0.352000
# lr 2.406586e-07 reg 3.801319e+04 train accuracy: 0.318163 val accuracy: 0.327000
# lr 2.606599e-07 reg 1.378644e+04 train accuracy: 0.339592 val accuracy: 0.351000
# lr 2.823236e-07 reg 6.778204e+03 train accuracy: 0.342857 val accuracy: 0.356000
# lr 3.057877e-07 reg 2.176051e+04 train accuracy: 0.335020 val accuracy: 0.350000
# lr 3.312019e-07 reg 1.125526e+04 train accuracy: 0.348020 val accuracy: 0.364000
# lr 3.587284e-07 reg 1.688685e+04 train accuracy: 0.338918 val accuracy: 0.363000
# lr 3.885425e-07 reg 1.069871e+04 train accuracy: 0.350633 val accuracy: 0.344000
# lr 4.208346e-07 reg 1.966169e+04 train accuracy: 0.329102 val accuracy: 0.332000
# lr 4.558105e-07 reg 5.421295e+04 train accuracy: 0.292204 val accuracy: 0.301000
# lr 4.936932e-07 reg 1.310473e+04 train accuracy: 0.348898 val accuracy: 0.359000
# lr 5.347244e-07 reg 6.443036e+03 train accuracy: 0.366816 val accuracy: 0.378000
# lr 5.791657e-07 reg 2.289250e+04 train accuracy: 0.324020 val accuracy: 0.332000
# lr 6.273006e-07 reg 6.124441e+03 train accuracy: 0.366265 val accuracy: 0.380000
# lr 6.794360e-07 reg 3.613351e+04 train accuracy: 0.311531 val accuracy: 0.341000
# lr 7.359045e-07 reg 5.153223e+04 train accuracy: 0.285327 val accuracy: 0.287000
# lr 7.970660e-07 reg 3.434678e+04 train accuracy: 0.311143 val accuracy: 0.307000
# lr 8.633107e-07 reg 5.000000e+03 train accuracy: 0.371878 val accuracy: 0.382000
# lr 9.350611e-07 reg 8.734442e+03 train accuracy: 0.356531 val accuracy: 0.368000
# lr 1.012775e-06 reg 2.408337e+04 train accuracy: 0.330694 val accuracy: 0.347000
# lr 1.096947e-06 reg 7.130808e+03 train accuracy: 0.358184 val accuracy: 0.355000
# lr 1.188115e-06 reg 6.000000e+04 train accuracy: 0.298020 val accuracy: 0.314000
# lr 1.286860e-06 reg 5.821600e+03 train accuracy: 0.351592 val accuracy: 0.357000
# lr 1.393812e-06 reg 5.533733e+03 train accuracy: 0.362347 val accuracy: 0.374000
# lr 1.509653e-06 reg 1.525810e+04 train accuracy: 0.336429 val accuracy: 0.346000
# lr 1.635121e-06 reg 8.302542e+03 train accuracy: 0.350612 val accuracy: 0.347000
# lr 1.771018e-06 reg 1.868946e+04 train accuracy: 0.324898 val accuracy: 0.337000
# lr 1.918208e-06 reg 2.665419e+04 train accuracy: 0.313408 val accuracy: 0.307000
# lr 2.077632e-06 reg 4.898406e+04 train accuracy: 0.263959 val accuracy: 0.275000
# lr 2.250305e-06 reg 5.703312e+04 train accuracy: 0.279776 val accuracy: 0.287000
# lr 2.437330e-06 reg 1.245673e+04 train accuracy: 0.326245 val accuracy: 0.334000
# lr 2.639898e-06 reg 2.533620e+04 train accuracy: 0.294367 val accuracy: 0.304000
# lr 2.859302e-06 reg 1.776531e+04 train accuracy: 0.311347 val accuracy: 0.322000
# lr 3.096940e-06 reg 3.264840e+04 train accuracy: 0.267265 val accuracy: 0.278000
# lr 3.354329e-06 reg 1.605183e+04 train accuracy: 0.317980 val accuracy: 0.317000
# lr 3.633110e-06 reg 1.016969e+04 train accuracy: 0.323592 val accuracy: 0.320000
# lr 3.935061e-06 reg 4.656190e+04 train accuracy: 0.248959 val accuracy: 0.255000
# lr 4.262106e-06 reg 2.068450e+04 train accuracy: 0.299102 val accuracy: 0.305000
# lr 4.616333e-06 reg 2.949944e+04 train accuracy: 0.200449 val accuracy: 0.202000
# lr 5.000000e-06 reg 2.804075e+04 train accuracy: 0.230592 val accuracy: 0.251000
# best validation accuracy achieved during cross-validation: 0.382000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.369000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
